# %%
from transformers import pipeline

# This model is a `zero-shot-classification` model.
# It will classify text, except you are free to choose any label you might imagine
classifier = pipeline(model="facebook/bart-large-mnli")
classifier(
    """Штирлиц, на вас поступил донос от соседей. Пишут, что вы вчера пили, буянили и ругались по-русски!
	Штирлиц молча берёт лист бумаги и пишет ответный донос:
	"Группенфюреру СС Генриху Мюллеру. Мои соседи знают русский язык и, что особенно подозрительно, разбираются в ненормативной русской лексике!""",
    candidate_labels=["смешно", "грустно", "агрессивно", "обычно", "философично"],
)
# Out:
# c:\Users\mievst\anaconda3\envs\viral_videos\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# {'sequence': 'Штирлиц, на вас поступил донос от соседей. Пишут, что вы вчера пили, буянили и ругались по-русски!\n\tШтирлиц молча берёт лист бумаги и пишет ответный донос:\n\t"Группенфюреру СС Генриху Мюллеру. Мои соседи знают русский язык и, что особенно подозрительно, разбираются в ненормативной русской лексике!',
#  'labels': ['смешно', 'грустно', 'обычно', 'агрессивно', 'философично'],
#  'scores': [0.3616945445537567,
#   0.304428368806839,
#   0.1545340120792389,
#   0.10165932774543762,
#   0.07768379151821136]}

# %%
from transformers import pipeline

# This model is a `zero-shot-classification` model.
# It will classify text, except you are free to choose any label you might imagine
classifier = pipeline(model="cointegrated/rubert-base-cased-nli-threeway")
classifier(
    """Штирлиц, на вас поступил донос от соседей. Пишут, что вы вчера пили, буянили и ругались по-русски!
	Штирлиц молча берёт лист бумаги и пишет ответный донос:
	"Группенфюреру СС Генриху Мюллеру. Мои соседи знают русский язык и, что особенно подозрительно, разбираются в ненормативной русской лексике!""",
    candidate_labels=["смешно", "грустно", "агрессивно", "обычно", "философично"],
)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# {'sequence': 'Штирлиц, на вас поступил донос от соседей. Пишут, что вы вчера пили, буянили и ругались по-русски!\n\tШтирлиц молча берёт лист бумаги и пишет ответный донос:\n\t"Группенфюреру СС Генриху Мюллеру. Мои соседи знают русский язык и, что особенно подозрительно, разбираются в ненормативной русской лексике!',
#  'labels': ['смешно', 'агрессивно', 'грустно', 'философично', 'обычно'],
#  'scores': [0.4557251036167145,
#   0.2718726098537445,
#   0.2234349399805069,
#   0.03288855403661728,
#   0.016078822314739227]}

# %%
import json

def create_ngrams_by_time_and_duration(chunks, max_overlap=0.5, target_duration=10.0):
    ngrams = []
    i = 0

    while i < len(chunks) - 1:
        # Начальные значения для первого чанка
        current_start, current_end = chunks[i]["timestamp"]
        ngram_text = chunks[i]['text']
        ngram_start = current_start
        ngram_end = current_end
        ngram_duration = ngram_end - ngram_start

        # Объединение чанков, если они не превышают заданную длительность
        while i < len(chunks) - 1:
            next_start, next_end = chunks[i + 1]["timestamp"]
            next_duration = next_end - next_start

            # Пересечение по времени
            overlap = max(0, min(current_end, next_end) - max(current_start, next_start))

            # Проверяем условие на пересечение и целевую длительность
            if overlap / min(ngram_duration, next_duration) <= max_overlap and (ngram_duration + next_duration) <= target_duration:
                # Обновляем энграмму
                ngram_text += " " + chunks[i + 1]['text']
                ngram_end = next_end
                ngram_duration = ngram_end - ngram_start
                i += 1  # Продвигаемся к следующему чанку
            else:
                break

        # Добавляем текущую энграмму в список
        ngrams.append({"text": ngram_text, "timestamp": [ngram_start, ngram_end]})
        i += 1  # Переходим к следующему чанку

    # Обрабатываем последний чанк, если он не вошел в энграмму
    if i < len(chunks):
        ngrams.append({"text": chunks[i]['text'], "timestamp": chunks[i]["timestamp"]})

    return ngrams


with open("./result.json", "r") as f:
    chunks = json.load(f)

chunks = chunks["chunks"]
# Применение функции
ngrams = create_ngrams_by_time_and_duration(chunks, target_duration=120.0)

# Вывод результата
for ngram in ngrams:
    print(f"Текст: {ngram['text']}\nВременные метки: {ngram['timestamp']}\n")
# Out:
# Текст:  всем привет это киц кухня шоу где дети становятся на кухне главными с вами я мария перышкина и мой  сын мирон давай 5 и сегодня у нас в гостях многократная чемпионка мира и Европы, дважды призер Олимпийских игр и просто крутая девушка и мама Ирина Слуцкая с дочерью Варварой.  Любишь ли ты готовить?  Да.  А какие твои самые любимые кулинарные шедевры мои самые любимые кулинарные шедевры это тортики которые я делаю практически каждую  субботу и карбонару которую мы делаем вместе с мамой а также мы любим делать беляши и разные  пирожки с кокосом ничего себе ладно как вы думаете что сегодня вы будете готовить но очень хотелось  бы на самом деле из рыбки что-нибудь сделать потому что я люблю рыбку ав авокадо. То есть что-то такое прям легкое. Мирон, а ты как думаешь, что мы сегодня будем делать?  Я? Я думаю, что мы будем мстить.  Мстить?  Конечно.  Да, Варвар?  Ну, готовить всякие невкусные блюда.  Да, и что же вы будете такое готовить и за что мстить?  За то, что надо ходить в садики, ехать в школу.  Все, все.  Какая тяжелая у вас жизнь, ребят.  Маша, скажи, пожалуйста, а как это вообще все будет происходить?  Как они это будут делать? Потому что, ну,  дети-то, в принципе, маленькие, а наверняка  задание будет более чем интересное,  продуктов наверняка будет много.  Как они с этим справятся?  Это самое интересное, потому что  правила нашего шоу такие,  что главной на кухне становятся дети.  И они могут готовить из всего, что есть на этом столе.  Детям будет помогать наш профессиональный повар.
# Временные метки: [0.0, 118.84]
#
# Текст:  Повар, повар, повар!  Давайте все дружно позовем нашего повара Алексея Царского!  Давайте! Привет! Привет всем привет всем привет ребят как дела как настроение отлично сегодня как я понял ты хочешь что-то легкое спортивное да да отлично и ты тоже у меня есть прекрасная идея это будет с рыбкой  это будет очень легко спортививно и вкусно.  Но для начала нам нужно с вами сходить в магазин, пока наши девчонки будут пить чай.  Супер! Мы можем вам сказать, удачные дороги и купите все самое-самое вкусное.  Конечно, а мы постараемся накормить вас сегодня самым-самым вкусным. Пойдемте.  Никаких шпрот и васаби в этот раз.  Да, может быть только кетчуп.  Конечно, конечнодачи. Да, может быть, только кетчуп. Конечно, конечно.  Ну, пока-пока.  Ира, мы с тобой пойдем в соседнюю комнату наблюдать, что же наши дети будут там покупать.  А они могут купить абсолютно все.  Это кошмар. Ну, пошли посмотрим.  Надеюсь, что купят все то, что нужно.  Надеюсь, в этот раз без васаби.  Ну что, ребята, вы готовы?  Да!  Тогда погнали!  А мы сейчас найдем.  Что ты принес? Твою любимую?  Вот такую.  Как он такая? Конечно, ты чего, обижаешь?  Давай, пойдет.  Для нашего ПП-майонеза нам очень нужна горчица.  Только как вы думаете, какая?  Русская дерзкая или все-таки французская сладкая?  Русская, давай.  А может быть, возьмем обе?  Давайте.  О, острый перчик.  Табаско, мне кажется.  Табаско.  Какой ужас.  Я не использую табаско.  Как думаешь, Варя добавит тебе табаско?  Я не знаю, это совершенно не наша еда.  У меня в доме табаско нет.
# Временные метки: [119.46, 239.6]
#
# Текст:  Мы острое вообще не едим.  Как порошок может быть  с битыми сливками?  Ну, если его развести, скорее всего, с водой.  Ну, это такая химоза.  То есть что, лучше настоящие сливки купить тогда.  Кстати, насчет сбитых сливок.  Как вам идея?  Очень хорошая.  С рыбкой-то, да?  Ох, прекрасно будет.  Слушай, ну я все понимаю.  Ну, хорошо, рыба.  А в сбитые сливки-то к чему вообще?  Сегодня у нас главные на кухне дети.  И они могут готовить, смешивать все продукты.  Васаби заливать, табаско, добавлять туда лосось в блендере,  взгущеночки, взбитые сливки и все маме.  О, горчица, горчица.  Вот и горчица, давайте смотреть, какую мы возьмем.  Самая дешевая за 19 рублей.  О, хрен, смотрите, хрен.  Вот такая хорошая, она прям для майонеза.  И возьмем какую-нибудь, вот что, знаешь, для остринки, так сказать.  Какую-нибудь...  Это паста.  Горчица русская.  Русская, да, именно.  Давай, отлично. Все, мы взяли, чтобы гопчица. Да, именно. Давай. Отлично.  Все, мы взяли, чтобы мстить это.  Да.  Чтобы мстить.  Ну что, ребят, мы с вами классно сходили в магазин,  закупили много интересных продуктов, в том числе  ПП, всякие вещи.  Тут очень много зелени, я вижу.  Прям молодцы.  Рыба красная, которую ты так хотела.  Для начала нам просто нужно просеять муку. Тут очень много зелени, я вижу. Прям молодцы. Рыба красная, которую ты так хотела.  Для начала нам просто нужно просеять муку.  Добавим немножко вкусной приправы,  чтобы наши лепешечки были не такими пресными.  Давай, я буду добавлять, а ты мешай.  Давай-давай интенсивнее.  Ты мне лучше расскажи, какие твои увлечения, кроме кулинарии,  может быть, там какие-то секции ты ходишь?  Ты же спортсменка, в свою маму прям.  Я занимаюсь фигурным катанием.  А ты, Мирон, умеешь кататься на коньках?
# Временные метки: [239.76, 359.58]
#
# Текст:  Нет.  Нет? А почему? Боишься упасть?  Да, я всегда на них падаю и просто нафиг не могу.  И тебя это расстраивает?  А может, когда подрастешь, это перерастется как-то и тебе прям захочется даже научиться?  Да?  Блин, не надо.  Мы сегодня с вами будем командой рисового теста.  Скажи, мне вот как той же маме троих интересно, вот у тебя есть какая-то, может быть, в голове спланированная схема, что там сын будет футболистом, дочь будет фигуристкой,  там младшая дочь будет врачом? Старшему 14, он в прошлом году для себя решил, что он хочет  поступить в институт гражданской авиации в Ульяновске.  Поэтому он четко идет к этой цели.  А я, как мама, пытаюсь  ему  помочь. То есть, да, я понимаю,  что он говорит, мне нужна математика.  Мне не хватает в школе математики,  я где-то что-то не успеваю. Мне нужен репетитор.  То есть, я вкладываюсь  в его образование. Он говорит, что я  должен выучить язык. Он учит три языка. То есть, максимумываюсь в его образование. Он говорит, что я должен выучить язык.  Он учит три языка.  То есть максимум, что я могу сделать,  его поддержать и помочь ему как-то осваивать эти языки.  Средняя сейчас просто болеет спортом.  Другого слова я не могу даже подобрать.  Значит, моя задача какая? Помочь ей.  Ей не хватает растяжки танцев. Значит,  к нам приходит педагог и занимается  индивидуально. Не хватает  занятий на тренировке. Где-то что-то она  не успевает доучить. Значит, моя задача  найти тренера для того,  чтобы тренер с ней индивидуально позанимался.  Маленькая еще,  совсем маленькая. Я очень хочу в художественную  гимнастику, а там уж не знаю,  как получится. Итак, у нас готово тесто. Мы сейчас с вами будем делать рисовые диетические репешки.  А скажите мне, а что такое диетическое? Диетическое – это когда ты не толстеешь,
# Временные метки: [359.96, 476.98]
#
# Текст:  но при этом можешь есть. Вы придерживаетесь правильного питания? Наверное, это очень сложно всегда находиться на правильном питании,  отказываться от каких-то продуктов.  Наверное, я стараюсь привить детям любовь к тем продуктам,  которые действительно приносят пользу,  и поменьше употреблять то, что вредно для организма.  Но скажу так, что у нас нет полного запрета на сладкое,  у нас нет полного запрета на какую-то продукцию,  которая действительно не всегда здоровой считается,  но всё в меру.  То есть если они хотят сладкое, то немного,  и лучше, конечно, в первой половине дня.  Если они хотят что-то уж совсем вредное,  и такое тоже бывает,  ну, можно, просто не каждый день,  а хотя бы раз в несколько месяцев.  Но мне кажется, что если ребенку полностью закрыть  доступ к каким-то продуктам,  то рано или поздно они сорвутся.  Поэтому лучше пускай они понемножечку это все,  как сказать, щипают,  нежели чем впоследствии набросится и съедят целый таз.  Берем ложку нашего жидкого теста,  кладем в середину.  А, ромашковое!  И нужно его немножко  разровнять по поверхности.  А, ромашковое масло!  Ромашковое масло? Это ты где взял такое?  Вон, вот там лежит.  Я боюсь, что это просто  подсолнечное, Мирон.  А что это Алексей делает?  Он рисовые лепешки жарит.  Как необычно. Я первый раз такое вижу.  Я тоже смотрю, прям не боится.  Расколю на сковородке рукой.  Опа, она начала ездить, видите?  Не совсем, конечно, у нас круглая  получается, но не все идеально в этом мире.  Правда, ребята?  Мне кажется, она выходит в виде такого полусердечка.  Ну вот видишь, какое у тебя романтическое настроение  сегодня, а? Да.  Она у меня всегда такая. Всегда такая?  Конечно. Кого я обманываю?  Как ты относишься к различным шоу-программам
# Временные метки: [476.98, 596.28]
#
# Текст:  детским, которые  не всегда несут пользу  детям? У детей на компьютере  у меня стоит защита,  и они не посещают  те сайты, которые у нас с ними  не согласованы.  К сожалению или к счастью, здесь, наверное,  очень сложно сказать,  они сами хозяева своих  телефонов и  могут, конечно, зайти куда-то  не туда. Но скажу так, что  какая бы... Дети,  вы меня сейчас не слушаете, мои дети.  Какая бы я  хорошая мама ни была, но  я смотрю их телефоны  и знаю,  что Артем у меня смотрит,  это сын мой старший,  просматривает контент, все, что  связано с самолетами.  Он очень много знает.  Он прям учится в интернете., смотрит какие-то блогеров,  которые рассказывают о том, как это летает, из чего это состоит. Варвара последнее время  выискивает очень много рецептов различных и реализует их на кухне. Она мне перевела просто  все продукты, какие только можно, но я этому не препятствую, пускай пробует, пускай развивается. Иной раз, конечно же, я ей говорю, Варя, давай мы как-то с умом подойдем к этой истории, но она прям что-то ищет, что-то готовит, так и злой и вредный. И я советую родителям все же смотреть и следить, что смотрят, что просматривают ваши дети.  Это очень важно.  Сколько мальчиков у тебя влюблено в классе?  У нас в классе какие-то недомальчики такие.  Это что значит недомальчики?  Ну, как вам сказать, как объяснить?  Клинжанты. значит не до мальчики? Ну, как вам сказать, как объяснить? Кринжанутый.  Вот уж этот современный сленг.  Кринжанутый.  А что это кринжанутый?
# Временные метки: [596.28, 715.44]
#
# Текст:  Кринжанутый это смешной,  прикольный, вот,  и такой... Немножко сумасшедший.  Немножко, да.  Самую малость.  И это все про нашего Мирошу.  Кстати, когда мы шли в магазин, я просто ей подарила шоколадку, и она меня обняла.  О, как это мило.  Запомните это, дети, и поставьте подписочку на канал и лайк за это.  На, держи.  Так, давай я тебе помогу давай давай подкидываем может быть  все береги ну все я просто люблю когда такая золотистая корочка ну так и нужно все верно  это не это честное слово не я это все он я пытаюсь его сдержать как могу, но у меня не получается.  Ай.  Так, аккуратно, аккуратно.  И тебе тоже на.  Так, тебя не видно.  Зачем там нос?  Не бойся, я тебя держу.  Давай.  Главное, только не трогай вот здесь ничего аккуратно, чтобы не обжечься.  Я тебе буду помогать.  Варь, и ты тоже помогай, будешь нам ее разравнивать.  А, я сам могу разравнивать.  Сам можешь разравнивать?  Какой ты молодец.  От себя, давай, от себя.  Веди от себя.  Вполне достаточно. Да кого я обманываю от себя. Веди от себя. Вполне достаточно.  Да кого я обманываю? Ладно, делаем дальше.  Вполне достаточно.  Вполне достаточно. Ну, раз ты так считаешь, все, молодец.  Пока наша последняя лепешка до конца дожаривается, в принципе, мы можем очистить наши яйца и желтки оттуда забрать.  Ну, чистить яйца я люблю.  Прям любишь?  Да. Давай тогда начинай мирон давай встанешь сейчас варя будешь помогать ей яйца чистить ты берешь яичко бери в две ручки и
# Временные метки: [716.2, 836.08]
#
# Текст:  вот так осторожно вот прямо так а я буду да отделяем да да это просто отделяем, да? Да, просто отделяем. Ничего страшного, если там есть яичко, ничего.  Нафиг отделяем это, нафиг, нафиг.  Нафиг, нафиг.  Это перед девчонкой, мне кажется, перед взрослой.  Давайте желтки сюда, не будем терять времени.  Что, любите белки?  Угу.  Даже без соли?  Да.  Мне кажется, это не очень вкусно. Не знаю, я всегда белки ела без соли мне кажется это не очень вкусно не знаю сюда был киева без соли варя на самом  деле старается следить за своим питанием при том что она делает торт и старается до что мы  очень любим макароны но при всем при этом она уже вот в своем возрасте четко понимает, что  вот это я съем сейчас,  а вот это я отложу на утро.  И когда я ей с собой складываю  еду, она каждый день  ездит с термосами,  она очень четко контролирует,  что у нее там в термосе. То есть мы встаем  достаточно рано, мы встаем в половине шестого с ней,  в шесть она уже выезжает  из дома. И я встаю, склад складывали все бутерброды суп  2 она так мам хлеба поменьше одну маленькую конфетку мне положи мама где огурец мам фруктов  мне положи то есть она пока собирается одним глазом блюдит что и там кладу а вообще вы знаете в каком году изобрели майонез и кто это  сделал мне кажется в 1910 году прекрасная прекрасная идея но нет нет майонез изобрел  французский повар в 1756 году на острове майон это был повар кардинала Ришелье. Добавляй  ложки нашего творога,  а я тебе скажу, когда остановиться.  Все, достаточно.  Молодец. А ты, Варь,  добавь горчицу.
# Временные метки: [836.08, 954.7]
#
# Текст:  Я думаю, половинки достаточно будет.  Хочешь всю?  Можно всю.  Какой поворот.  Варь, дай, пожалуйста, лимонон еще понадобится нам лимон вот пальцы  аккуратно давайте смотри вот так вот ставишь и так ты никогда не порежешься одним резким  движением тупой какой-то попробуй мой какой варька у меня девочка-катастрофа Да Она вот несет что-то  Из тарелки там, из доски  Смотри, смотри, смотри, лимон, лимон льет  Ты любишь лимоны, серьезно  С кожурой только, прям с кожурой  Ты знаешь, да, в этот челлендж? Правильно  Ну какой-то маленький кусочек ты отрезала  Мне кажется, можно и побольше  Так, что там в глазах у нас?  Молодец, аплодисменты да просто выжми прям не больше чем столовую ложку все столовая ложка есть и столовая ложка  от мироши ездят ну прям чуть-чуть выжми чтобы чтобы он хотя бы вкусный был у нас.  Мирон, что, ты будешь у нас главным взбивателем майонеза?  Да, я это сделаю. Только давай до самого низа сначала.  Да, да. Давай, давай, давай.  Молодец, сейчас мы тебе поможем.  А ты что там встала? Иди сюда.  А я на чили на расслабоне. На чили на расслабоне. а ты чё там стала иди сюда так мне интересно получилось поэтому эксперт варя сейчас это все  про про про пробует и прям вот отсюда и единственный там горчица многовато возможно  но вкусно но горчицы много все-таки потому что кто-то и и бухнул много  ложки не было чтобы поменьше давать короче соус у нас готов хотите может быть сюда что-нибудь еще
# Временные метки: [955.7, 1075.24]
#
# Текст:  добавить давай хороший хороший соус не надо портить слушайте мы столько всего накупили тут и дешевый паштет и добавим васаби  есть и горчица добавляем вас в асаби ну что поехали девушки пока вот это жестоко просто  я острая не могу вообще есть дети я предлагаю я просто хочу вас предупредить что у меня астма и если остро  будет вы менять в реанимацию загонить давай только не очень много и главное потом не трогай лицо  мирон пожалуйста не добавляй табаско ты сначала на пальчик попробуй все хватит хватит хватит хватит, хватит, хватит Мирон, ты их убьешь  Хватит  Так, давайте, кто?  Я  Давайте вместе  Я буду держать чашу, а вы вдвоем держите  И взбивайте наш адский вкусный соус  Все, хорошая дуня  Я считаю, что вы обязаны хотя бы чуть-чуть попробовать то, что вы наделали наш адский вкусный соус. Да все, хорошая дуня.  Я считаю, что вы обязаны хотя бы чуть-чуть попробовать то, что вы  наделали. Вот прям на кончике.  Даже я с вами попробую.  Вкусно, да? Не очень.  Что, водичку в студию, да?  А, ну, кстати, как вариант  клубника, да, молодец, хорошая идея.  Клубника освежает.  Мирон, пробуй.  Ну, не бойся.  Я вот попробовал, и у меня все нормально.  Адский соус тоже готов.  Мне кажется, то, что мы сделали очень классный соус,  но у меня такое ощущение, что потом наши мамы будут где-то,  ну, примерно где-то 4 тонны молока пить.  Слушай, ты вот просто клубничкой заела, и тебе, по-моему, очень хорошо.  Да мне вообще по кайфу.  Если начались, уже вот, все хорошо.
# Временные метки: [1075.24, 1193.44]
#
# Текст:  Мне, ну, мы сделали какой-то, что ты говоришь, адский соус.  Адский соус.  Кит-соус.  Кит-соус, так его и назовем, окей.  Кит-соус на Китс-кухне.  Кит-соус, так теперь называется. Так,. Окей, кит-соус на кит-кухне. Кит-соус, так теперь называется.  Так, ребят, ну что, у нас почти все готово.  Нам осталось только нарезать ингредиенты и собрать наши лепешечные бургеры.  Назовем их так.  Нарежем, я думаю, вот таким образом.  Вот тебе один раз показываю.  Прорезаешь, до конца нажимаешь и отделяешь от кожицы, чтобы кожица оставалась чистой, чтобы  потерь рыбы была минимальной.  Очень дети любят рыбу. Я очень часто  сталкиваюсь с тем, что у моих знакомых дети рыбу  не едят совершенно. Мои дети  обожают рыбу. Сырое мы не едим.  Мы  либо на гриле, либо  запеченную. Стараемся как можно меньше  жарить всего.  И они, правда, очень любят рыбу различную.  Сын у меня еще с дедом любит на рыбалку съездить  и всегда привозит какие-то трансферии.  Ну что-то у вас ксянет к воде всех.  У меня супруг тоже на рыбалку так вообще.  Мужики собираются очень быстро и активно.  Ир, скажи, ты участница  Олимпийских игр,  успешная карьера  в спорте, в фигурном катании.  Варя сейчас занимается  тоже фигурным катанием.  Ты как родитель  испытываешь  амбиции, чтобы она  повторила твой успех?  Мне очень хочется, чтобы мои дети прошли по своей судьбе.  У меня амбиции может быть миллион или даже миллиард.  Но у каждого своя судьба.  И, наверное, я как мама должна всегда готовить ребенка  к какому-нибудь запасному варианту.  Потому что желающих  действительно много, чемпионом становится  лишь один, так всегда говорила моя мама.  Я должна подготовить ее к тому,
# Временные метки: [1193.68, 1312.28]
#
# Текст:  чтобы она смогла войти  во взрослую жизнь,  даже без фигурного катания.  Поэтому, как бы она иной раз не хотела,  я считаю, что  образование должно быть в приоритете.  Ты знаешь, как  чистить авокадо?  Это спелый  авокадо. Прорезаем его вот таким  образом.  Далее  на две части разламываем.  Пробиваем косточку.  А он мне.  Косточка мне нужна. Он нам не еда.  Ты только не ешь ее, ладно так куда сказал же не ешь оскара надо не сетью скажу несите  оскара студию сейчас я уже ну дакуратнее. Я пока. Так, она не возьмется.  О, попал! Почти получилось, молодец.  Да дайте мне уже их в рот!  Сейчас, сейчас дадим, обязательно.  Все, я не могу ждать.  Смотри, Мирон у нас начал командовать у нас процессом.  Ну, мужчина, все взял в свои руки.  Давай, как мы любим.  О, круто, получилось. все взял свои руки давай как мы любим о  круто получилось челлендж выполнен  но дома то конечно не похулиганишь так не поразмазывать шлифки пока мама смотрит на экрана так ну что Так, ну что, ребят, все готово.  Осталось только собрать наши лепешечные бургеры.  Для начала положим соус.  А можно сама?  Конечно, да, держи.  Ну, если тебе все равно, я положу побольше.  Теперь что-нибудь свежего.  Такого прямо освежающего.  Как насчет листьев романа?  Отлично.  Отлично.  Листья романа.  Все, вот это то что надо вкусно тебе да
# Временные метки: [1312.42, 1427.32]
#
# Текст:  мирон ты не отвлекайся тут уже за тебя твой бургер делаю я положил соус листья романа немножко шпината  чего тебе советую давай огурчиков все верно и прям по богатому на рыбке положить как ты думаешь так  вот носик из этого а что мы будем делать с тем, что вы накупили еще, а?  Неужели мы это никуда не используем?  Используем, конечно, обижается.  Мне кажется, что это было бы  несправедливо по отношению к производителям  данной продукции. Да.  Имеется паштет.  Так, ей один, мне второй.  Ядреная столичная горчица.  Ей один, мне второй.  И даже есть сгущенное молоко. даже не знаю что вы придумаете я умываю руки если мама это не с  тест ты заставлю съесть ну варвара жди варвара пор Параштет рыбный.  Я положу прям.  Давай, давай, прям сюда.  Да пальцем прям размазывай, ничего страшного.  Мам, тебе будет вкусно, я обещаю.  Что-то как-то раньше у меня настроение было лучше.  Ну там реально теперь васаби у нас и что-то табаско.  Мам, я вас очень люблю.  Говорю, будет вкусно все.  И даже она немножко вкуснее, но у меня тоже вкусно.  Ты же хотел сливок добавить.  Лишний.  Помнишь, сверху и малинку положить.  А, да, да, да.  Давай.  Опа.  Подожди секунду.  Надо сначала вот так сделать.  Ты вот так вот делай.  Вот так вот сделать ты хотел, да?  Чтобы красивенько было, да?  А сверху мы добавляем финалочку.  Финалочку. Супер. Красота.  Мы можем уже почти что звать наших мам на дегустацию,  но сначала мы должны придумать, как же мы это назовем.  И съесть огурчики.
# Временные метки: [1427.32, 1543.42]
#
# Текст:  У тебя похоже на остров какой-то, я бы сказал, в океане, необитаемый. Остров любви. Остров любви? Да. Ну да, в принципе, у Мирона тоже такая здесь получается,  типа как... На корабль. Горы. Мне кажется на корабль. Нет, корабль, да, корабль. Так, значит, у тебя будет остров любви, а у тебя...  Сердечный корабль.  Сердечный корабль и остров любви.  Ира, ну мне кажется, нам уже пора идти пробовать кулинарный шедевр, который сделали наши дети.  Ты готова?  Ну что ж, пошли.  Раз, надо.  Мамы пришли.  Что это?  Какая красота.  Мирон, как вы это назвали?  Как вкусно пахнет.  Это вот ваша сердечный корабль.  Сердечный? Сделал нас любовью?  Добавил сюда.  Секрет, секрет. Ого, смотрите. Ну как? сделала с любовью добавил сюда так смотрите ну как запомнила блинчик  костей да ну острый не знаю у меня более чем все может быть еще не дошла до истины Не туши, я не плачу. Какой добрый мальчик. Не туши, ты есть? Как у тебя? Не туши, ты есть?  По-моему, я решила согласиться.  Могу предложить швит и сироп.  Это все.  У меня уже горит во рту.  Мирон, что там?  Алексею нужно попробовать свой кулинарный шедевр.  Так это же не я готовил, а дети.  Я только координировал.  Как это, ежики плакали, кололись, но продолжали есть кактусы.  Давай, давай, давай, давай.  Ну ладно, говорили.
# Временные метки: [1549.18, 1670.02]
#
# Текст:  Самолетик летит.  И закусит сливками.  С виноградинкой.  Ура!  Аккуратно.  Туда.  Ура!  Мирон, давай ему сливок еще туда.  Сердечко.  Не надо мне сливок, я вас убью.  Самое яркое испытание, конечно, съесть то, что приготовили,  но я считаю, что мне немножко больше повезло, чем тебе.  Единственное, что горит просто все,  потому что, видимо, табаско там было и всего остального в нормальном количестве.  Я думаю, что главное сейчас спичку не подносить ко мне, иначе это все взорвется.  Все взорвется, да?  Слезы, нос, все. Ой, ужас какой.  А так, в принципе, паштет несъедобный, а все остальные ингредиенты более чем достойны для того, чтобы их есть.  Может быть, не в тех порциях.  Постарались, постарались.  У нас чуть-чуть порадовали.  Смитая пушка! быть не в тех постарались постарались у нас чуть порадовали да надеюсь вы успели  записать рецепт смотрите нас уже совсем скоро всем пока пока Woo!
# Временные метки: [1670.28, 1753.92]

# %%
from transformers import pipeline

# This model is a `zero-shot-classification` model.
# It will classify text, except you are free to choose any label you might imagine
classifier = pipeline(model="cointegrated/rubert-base-cased-nli-threeway")
classifier(
		ngrams[0]['text'],
		candidate_labels=["юмор", "вдохновение", "шок", "негатив", "удивление"],
	)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# {'sequence': ' всем привет это киц кухня шоу где дети становятся на кухне главными с вами я мария перышкина и мой  сын мирон давай 5 и сегодня у нас в гостях многократная чемпионка мира и Европы, дважды призер Олимпийских игр и просто крутая девушка и мама Ирина Слуцкая с дочерью Варварой.  Любишь ли ты готовить?  Да.  А какие твои самые любимые кулинарные шедевры мои самые любимые кулинарные шедевры это тортики которые я делаю практически каждую  субботу и карбонару которую мы делаем вместе с мамой а также мы любим делать беляши и разные  пирожки с кокосом ничего себе ладно как вы думаете что сегодня вы будете готовить но очень хотелось  бы на самом деле из рыбки что-нибудь сделать потому что я люблю рыбку ав авокадо. То есть что-то такое прям легкое. Мирон, а ты как думаешь, что мы сегодня будем делать?  Я? Я думаю, что мы будем мстить.  Мстить?  Конечно.  Да, Варвар?  Ну, готовить всякие невкусные блюда.  Да, и что же вы будете такое готовить и за что мстить?  За то, что надо ходить в садики, ехать в школу.  Все, все.  Какая тяжелая у вас жизнь, ребят.  Маша, скажи, пожалуйста, а как это вообще все будет происходить?  Как они это будут делать? Потому что, ну,  дети-то, в принципе, маленькие, а наверняка  задание будет более чем интересное,  продуктов наверняка будет много.  Как они с этим справятся?  Это самое интересное, потому что  правила нашего шоу такие,  что главной на кухне становятся дети.  И они могут готовить из всего, что есть на этом столе.  Детям будет помогать наш профессиональный повар.',
#  'labels': ['вдохновение', 'удивление', 'юмор', 'шок', 'негатив'],
#  'scores': [0.42336615920066833,
#   0.265536367893219,
#   0.25002264976501465,
#   0.046925220638513565,
#   0.014149677939713001]}
